# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Configuração de Web App Manifest para PWA\n",
    "Este notebook documenta a criação de `manifest.json`, a adição de `theme-color` no HTML e a geração de ícones PWA."
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 1. Configurar manifest.json para PWA\n",
    "Crie `manifest.json` com propriedades como `name`, `short_name`, `start_url`, `display`, `background_color`, `theme_color` e `icons`."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "manifest = {\n",
    "    \"name\": \"Busca CEP\",\n",
    "    \"short_name\": \"CEP\",\n",
    "    \"start_url\": \"/\",\n",
    "    \"display\": \"standalone\",\n",
    "    \"background_color\": \"#ffffff\",\n",
    "    \"theme_color\": \"#4fc3f7\",\n",
    "    \"icons\": [\n",
    "        {\"src\": \"/icons/icon-192x192.png\", \"sizes\": \"192x192\", \"type\": \"image/png\"},\n",
    "        {\"src\": \"/icons/icon-512x512.png\", \"sizes\": \"512x512\", \"type\": \"image/png\"}\n",
    "    ]\n",
    "}\n",
    "import json\n",
    "with open('manifest.json', 'w', encoding='utf-8') as f:\n",
    "    json.dump(manifest, f, indent=2, ensure_ascii=False)\n",
    "print('manifest.json criado.')"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 2. Adicionar link rel=\"manifest\" no HTML\n",
    "Insira `<link rel=\"manifest\" href=\"/manifest.json\">` no `<head>` do HTML para referenciar o manifesto."
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 3. Definir meta theme-color no HTML\n",
    "Adicione `<meta name=\"theme-color\" content=\"#4fc3f7\">` para personalizar a barra de ferramentas em navegadores móveis."
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 4. Gerar e incluir ícones no manifesto\n",
    "Crie os ícones nos tamanhos recomendados e referencie-os no `manifest.json` para instalação como aplicativo."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "from PIL import Image\n",
    "sizes = [(192, 'icons/icon-192x192.png'), (512, 'icons/icon-512x512.png')]\n",
    "for size, path in sizes:\n",
    "    img = Image.new('RGBA', (size, size), (79, 195, 247, 255))\n",
    "    img.save(path)\n",
    "    print(f'Criado {path}')\n"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 5. Testar e validar o manifesto no navegador\n",
    "Use ferramentas de desenvolvedor para verificar o manifesto e testar o comportamento PWA. Abra o Application > Manifest no Chrome DevTools."
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.x"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
